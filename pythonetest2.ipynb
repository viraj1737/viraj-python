# %% [markdown]
# 1

# %%
class student:
    school_name = "upes"

    def __init__(self,name,age):
        self.name = name
        self.age = age

s1 = student("viraj",20)
s2 = student("hitesh",23)

print("school:",s1.school_name)
print("student 1:",s1.name,s1.age)
print("student 2:",s2.name,s2.age)
# Out:
# school: upes
# student 1: viraj 20
# student 2: hitesh 23

# %% [markdown]
# 2

# %%
class employee:
    company = "ABC Ltd"

    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    
    def show_details(self):
        print(self.name,self.salary,employee.company)

        @classmethod
        def change_company(cls,new_name):
            cls.company = new_name


e1 = employee("viraj",30000)
e2 = employee("riya",40000)

e1.show_details()
employee.change_company("XYZ Ltd")
e1.show_details()
# Out:
# viraj 30000 ABC Ltd
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 20
#      17 e2 = employee("riya",40000)
#      19 e1.show_details()
# ---> 20 employee.change_company("XYZ Ltd")
#      21 e1.show_details()
#
# AttributeError: type object 'employee' has no attribute 'change_company'

# %% [markdown]
# 3

# %%
class mathhelper:

    @staticmethod
    def is_even(num):
        return num % 2 == 0

print(mathhelper.is_even(8))
print(mathhelper.is_even(11))
# Out:
# True
# False

# %% [markdown]
# 4

# %%
class bankaccount:
    
    def __init__(self,name):
        self.name = name
        self.__balance = 0 

    def deposite(self,amount):
        self.__balance += amount
        print("deposited:",amount)


    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("withdraw:",amount)
        else:
            print("insufficeinet balance")

    def show_balance(self):
        print("current balance",self.__balance)

acc = bankaccount("aman")

acc.deposite(5000)
acc.withdraw(2000)
acc.show_balance()
# Out:
# deposited: 5000
# withdraw: 2000
# current balance 3000

# %% [markdown]
# 5

# %%
class student:

    def __init__(self,name,age):
        self.name = name
        self.age = age

    def show(self):
        print("name:",self.name,"age:",self.age)

print("class name",student.__name__)
print("docstring",student.__doc__)
print("module",student.__module__)
print("class distionary",student.__dict__)
# Out:
# class name student
# docstring None
# module __main__
# class distionary {'__module__': '__main__', '__firstlineno__': 1, '__init__': <function student.__init__ at 0x10dd6a840>, 'show': <function student.show at 0x10dd69b20>, '__static_attributes__': ('age', 'name'), '__dict__': <attribute '__dict__' of 'student' objects>, '__weakref__': <attribute '__weakref__' of 'student' objects>, '__doc__': None}

# %% [markdown]
# 6

# %%
class product:
    def __init__(self,name,price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"product:(self.name),price:{self.price}:"

    def __add__(self,other):
        return self.price + other.price

    def _eq__(self,other):
        return self.price == other.price

p1 = product("laptop",50000)
p2 = product("phone",50000)
p3 = product("tablet",50000)

print(p1)
print( p1 + p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# product:(self.name),price:50000:
# 100000
# False
# False
