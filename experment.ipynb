# %% [markdown]
# # Python Programming Lab

# %% [markdown]
# ## Experiment 1: Python Installation and starting with python

# %% [markdown]
# #### 2. Write Python programs to print strings in the given manner:
#
# a) Hello Everyone !!!
#
# b) Hello
# World
#
# c) Hello
#        World

# %%
print("hello everyone")
# Out:
# hello everyone

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print('hello \n world')
# Out:
# hello
#  world

# %% [markdown]
# #### 3. Declare a string variable called x and assign it the value “Hello”.
# #### Print out the value of x

# %%
x = "hello"
print(x)
# Out:
# hello

# %% [markdown]
# #### 4. Take different data types and print values using print function.

# %%
name = "viraj"
age = 56
height = 90
is_student = True
print(name)
print(age)
print(height)
print(is_student)
# Out:
# viraj
# 56
# 90
# True

# %% [markdown]
# #### 5. ake two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together.

# %%
a = "viraj"
b = "kumar"

print(a + " " + b)
# Out:
# viraj kumar

# %% [markdown]
# #### 6.Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last n ame. Example output: George (woody) Washington.

# %%
first_name = "viraj"
last_name = "kumar"
nickname = "viru"

print(first_name + " (" + nickname + ")"+ last_name)
# Out:
# viraj (viru)kumar

# %% [markdown]
# #### 7. NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# Bidholi Campus
# Pincode: 248007

# %%
name = "nikunj bansal"
sap_id = 500069944
dob = "13 oct 1999"
address = "UPES\nbidholi campus"
pincode = 248007

print("name:",name)
print("sap id:",sap_id)
print("date of birth:",dob)
print("address:",address)
print("pincode:",pincode)
# Out:
# name: nikunj bansal
# sap id: 500069944
# date of birth: 13 oct 1999
# address: UPES
# bidholi campus
# pincode: 248007

# %% [markdown]
# ## Experiment 2: Use of input statements, operators

# %% [markdown]
# #### 1.Declare these variables (x, y and z) as integers. Assign a value of 9 to x. Assign a value of 7 to y, perform addition, multiplication, division and subtraction on these two variables and print out the result.

# %%
x = 9 
y = 7

print("addition:",x + y)
print("multiplication:",x * y)
print("division")
# Out:
# addition: 16
# multiplication: 63
