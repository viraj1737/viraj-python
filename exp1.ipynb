# %% [markdown]
# #### 	1.	Install Python and understand difference between scripting and interactive modes in IDLE.

# %% [markdown]
# Interactive Programming is when we run the code directly on the terminal. Here, every line is executed and the output is given in an instant. Continuos interlinked commands are not possible in interactive mode of python. We do not need to save anything in order to run the code.
#
# Whereas,
#
# In the script mode of python, we write the whole code and then it is executed at once as a whole. We need to save the file in order to execute it. In the case of python, the terminal command is “python -file name”

# %% [markdown]
# #### 2. Write python programs to print string in the given manner:
#
# a) Hello Everyone !!!
#
# b) Hello
# World
#
# c) Hello
#   World
#
# d) Rohit’s date of birth is 12\05\1999

# %%
print("hello UPES !!!")
# Out:
# hello UPES !!!

# %%
print("hello \nworld")
# Out:
# hello
# world

# %%
print("hello\n\tworld")
# Out:
# hello
# 	world

# %%
print("viraj's date of birth 12\\05\\8829")
# Out:
# viraj's date of birth 12\05\8829

# %% [markdown]
# #### 3. Declare a sting variable called x and assign it the value "hello". print out the value of x

# %%
x = "hello"
print(x)
# Out:
# hello

# %% [markdown]
# #### 4. take different data types and print values using print function.

# %%
a = 28
b = "hitesh"
c = 21.08
d = True
print(a)
print(b)
print(c)
print(d)
# Out:
# 28
# hitesh
# 21.08
# True

# %% [markdown]
# #### 5. Take two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together.

# %%
f_name = "viraj"
l_name = "kumar"
print(f_name + " " + l_name)
# Out:
# viraj kumar

# %% [markdown]
# #### 6.  Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last name. Example output: George (woody) Washington.

# %%
f_name = "viraj"
m_name = "kumar"
l_name = "singh"
print(f_name+" ("+m_name+") "+l_name)
# Out:
# viraj (kumar) singh

# %% [markdown]
# #### 7. Declare and assign values to suitable variables and print in the following way:
#
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
#   Bidholi Campus
#   Pincode: 248007
# Programme: AI & ML
# Semester: 2

# %%
name = "NIKUNJ BANSAL"
id = 590024814
dob = "13 Oct 1999"
add = "UPES\n\tBidholi Campus\n\tPincode: 248007"
prog = "AI & ML"
sem = 2

print("NAME:", name)
print("SAP_ID:", id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:", add)
print("PROGRAMME:", prog)
print("SEMESTER:", sem)
# Out:
# NAME: NIKUNJ BANSAL
# SAP_ID: 590024814
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# 	Bidholi Campus
# 	Pincode: 248007
# PROGRAMME: AI & ML
# SEMESTER: 2
